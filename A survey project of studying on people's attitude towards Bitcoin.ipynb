# %% [markdown]
# # A survey project of studying on people's attitude towards Bitcoin

# %% [markdown]
# ## Research topic and background
#
# Bitcoin is the first distributed cryptocurrency. Zhang (2021) reported the vast popularity of bitcoin and a consistent growing awareness ratio on a global scale in recent years. Moreover, the report described the wide fluctuation in Bitcoin's price since its first physical transaction of exchanging 10,000 mined Bitcoin for two pizzas in Florida, May 2010. The volatile price in Bitcoin attracts broad awareness. Many studies tried to use machine learning to forecast price trends. However, many factors drive Bitcoin price, such as economics and technology(Cai et al, 2022). Many studies tried to forecast bitcoin prices with a single driver, such as (Panagiotidis, Stengos and Vravosinos, 2019). However, such approaches overlooked the complexity of multi-driver impact. Cai et al (2022) reported a risk scenario-based approach and found that policy risks posed the severest impact on Bitcoin price.
#
# However, the policies announced on Bitcoin varies from country to country. El Salvador became the first country to use Bitcoin as legal tender in Sep 2021(Pérez, 2021). Legal tender is defined as a form of money that courts of law are required to recognise as satisfactory payment for any monetary debt (Wikipedia, 2022). Hence, the acceptance of legal tender money is imposed by-laws(Abu-Bakar, 2018). On the other side, John, Shen and Wilson (2021) reported that China issued a blanket ban on all cryptocurrencies to root out cryptocurrency activities. More countries are found in different attitudes towards Bitcoin. Finland allows and imposes taxes on Bitcoin transactions, while Estonia concludes neither regulations nor obstacles on the usage of Bitcoin (Wikipedia, 2022).
#
# Many studies tried to evaluate Bitcoin as a legal currency. Baur, Hong and Lee (2018) concluded Bitcoin as a speculative investment and not as an alternative currency and medium of exchange. Notetheless, Hui et al (2020) concluded that Bitcoin behaved as currency between fiat money and a crypto-commodity in the monetary modelling. Fiat money is legal tender that is not backed by any commodity (Wikipedia, 2022).
#
# Bitcoin legality is probably the cornerstone where many studies and policies are played. This project is motivated to investigate the trend of Bitcoin becoming legal tender. By declaring an item legal tender, sufficient demand might be generated to determine the medium of exchange (Luther, 2019). Howarth (2022) reported that more than 81 million people created unique Bitcoin wallets on Blockchain.com as of March 2022, an increase of 72% from the previous year. The sharp increase in Bitcoin demand might suggest a strong voice in the population for the legality of Bitcoin. This project's scope is to analyse how Bitcoin is supported as a legal tender in population. The study may provide insights on areas of studies on price prediction and digital currency. Bitcoin investment is not in the scope of this project. However, the study could provide insights to understand and direct Bitcoin investment behaviours.
#
# The following research questions were addressed in this project which could be answered by relative objectives:
#
# What are people's attitudes to grant Bitcoin as legal tender?
# The objective is to explore the population's attitude on Bitcoin legality by collecting and analysing people's voting data to grant Bitcoin as legal tender, which mapped to survey question "7.	Do you support or against to grant Bitcoin as legal tender in your country?"
#
# How do different backgrounds impact people voting options? The objective is to evaluate the sample's representativeness to the population and assess demographic features' association with people's attitudes, which mapped to demographic survey questions including age, gender, education level and salary level. Bitcoin awareness was also checked in these survey questions.
#
# How do bitcoin features contribute to people's votes?
# The objective is to evaluate the importance of Bitcoin features to Bitcoin legality. This evaluation was done by gathering voters' ratings on how each bitcoin feature contributed to their votes with the Likert scale type questions. Features investigated in this project were reviewed in the report of (Zhang, 2021)
#
# This report included five sections. The following section is data collection and survey design, followed by data analysis. The subsequent section explored the Bitcoin legal status worldwide from public data. Finally, a conclusion section summarised all the findings.

# %% [markdown]
# ## Data collection and survey design

# %% [markdown]
# ### Survey data collection
#
# This project used a quantitative approach to explore Bitcoin legality acceptance in the population by a public survey method. The project scope included a survey on Bitcoin legality acceptance by the sample data and public data describing existing Bitcoin legality status across countries. The scope of the survey included exploring respondents' attitudes to Bitcoin as legal tender and factors that may influence these attitudes. Factors could come from both respondents' backgrounds and Bitcoin's features. Research questions and objectives are set in accordance with the scope as above.

# %% [markdown]
# ### Survey design
#
# Type of questions An assorted type of questions, including multiple-choice questions and open-ended questions, were adopted in this survey. A block-level survey flow was adopted in this project, where each research question formed a block (as below). A pre-test was run before the release of the survey. A final number of 71 responses was collected.
#
# In this project, a public survey method is used. The survey was structured as below.
#
# Introduction.
#
# Survey questions on demographic features or backgrounds.
#
# Survey questions on voters' awareness and stance on Bitcoin.
#
# Survey questions on how Bitcoin typical features impact participants' votes.

# %% [markdown]
# ### Public data collection
#
# People's attitude on Bitcoin's legality could be compared with the actual Bitcoin legal status across countries to understand gaps or trends. Wikipedia is a free encyclopedia and the largest and most popular reference website in the world(Ayers, Matthews and Yates, 2008). Wikipedia platform consistently publishes up-to-date data based on information collected from the public. In this project, data were collected from Wikipedia articles. However, the list of countries is incomplete. As of Mar 2022, there are ninety-two countries listed on the website with details of Bitcoin legality status traceable references. There are five categories built accordingly, Legal tender, Permissive(it's legal to use bitcoin), Contentious(some legal restrictions on usage of bitcoin), Contentious(interpretation of old laws, but bitcoin is not prohibited directly), Hostile (full or partial prohibition) and No data. The contentious categories will be consolidated as one category in this project. Each category is appropriately mapped with a unique colour on the map. However, these categories are not explicitly described in line with the content. Hence, this project manually traced different records to match each country to a category by cross-checking the description and the colour map. Additionally, more countries are not listed as the information is not available. Dadax Limited (2022) reported a total of 195 countries in the world. Hence, the project imputed unlisted countries by Wikipedia as dummies and grouped them under the 'No Data' category.

# %% [markdown]
# ### Sample and Population:
#
# It may sound reasonable to include all adults all over the world as long as they make transactions with currency. However, due to the time limit and survey's reach in scale, this survey only targeted the adult English speakers worldwide as the survey came in the form of English language. There is a probable bias that the survey sample is not representing the population of different languages. However, that is not within our project scope. The sampling tried to reach a wider population as possible, including the UOL students, surveyor's social networks and so on. Different types of popular forums will be included to increase sample randomness. However, the starting point of the survey would be closely related to the surveyor's social network. Hence, each participant was requested to invite two more participants to the survey. Hence, the survey could be randomly distributed without the control of the surveyor. Seventy-one responses were collected. The response rate was higher than expected due to wide invitations to social networks.

# %% [markdown]
# ## Data overview and pre-processing
#
# In recent years, the violent fluctuation inspired wide awareness of Bitcoin, and many studies have been made forecasting the price trends and legality. Policies risks were ranked to be extreme risk factors impacting Bitcoin price. However, the trend in Bitcoin legality is still unknown. This survey inspected people's trend to grant Bitcoin as legal tender. Data were collected and analysed as follows to find whether there are clear trends in the population and how factors including demographic and Bitcoin features could impact or relate to such trends.

# %% [markdown]
# ### Import libraries for data analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Enable Matplotlib mode
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Load survey data

# %%
df = pd.read_excel('results-for-survey.xlsx')

# %%
df.head(1)
# Out:
#   1. What is your year of birth? 2. What is your gender ?  \
# 0                           1994                     Male
#
#   3. What is your highest education level?  \
# 0                Master's degree and above
#
#   4. Which of the following best describes your personal income last year (in USD)?  \
# 0                                   50,000 to 99,999
#
#   5. Do you know Bitcoin?  \
# 0                     Yes
#
#   6. Do you support or against to grant Bitcoin as legal tender in your country?  \
# 0                                      I am not sure
#
#    7. How likely do the below Bitcoin features contribute to your stance of support or against to grant bitcoin as legal tender?  \
# 0                                                NaN
#
#   7.1. Bitcoin is free from banks or governments manipulation  \
# 0                                        Very likely
#
#   7.2. A few people owned most of Bitcoins, they can manipulate price  \
# ...

# %% [markdown]
# #### Data preview

# %% [markdown]
# Data preview can help us gain a overview on data and understand areas to be improved as tidy data for analysis.

# %%
df.shape
# Out:
# (71, 17)

# %% [markdown]
# There are 71 observations and 17 features

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 17 columns):
#  #   Column                                                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                                                         --------------  -----
#  0   1. What is your year of birth?                                                                                                 71 non-null     object
#  1   2. What is your gender ?                                                                                                       71 non-null     object
#  2   3. What is your highest education level?                                                                                       71 non-null     object
# ...

# %% [markdown]
# Data type for all columns are object except column ' 7. How likely do the below Bitcoin features contribute to your stance of support or against to grant bitcoin as legal tender?', which consist all null values. There is no null value for other columns

# %% [markdown]
# #### Data preprocessing

# %% [markdown]
# To better visualize and explore trends in data, the missing or abnormal values, length column names, improper data types will be handled before exploration

# %% [markdown]
# #### Renaming columns

# %% [markdown]
# To the convenience of analysis and produce better visualization quality, all the survey questions will be renamed in a shortform for analysing convenience and better visualization. Shall there be any dispute in understanding of shortform, please refer to below chart for reference.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# rename columns with new names 

def rename_columns(df, new_names):
    rename_dict = dict(zip(df.columns, new_names))
    df = df.rename(mapper=rename_dict, axis=1)
    return df

# %%
new_names = ['age', 'gender','educationLevel', 'incomeLevel', 'bitcoinAwareness', 'vote', 'reasonsForVote',\
             'freeFromGov','pricingByMajorOwners', 'scarcity', 'noIntrinsicValue','paymentConvenience', \
             'riskyDigitWallet','freelyTraded', 'fraudTendency','lowTransactionFee','costyMining']

# %%
df = rename_columns(df, new_names)
df.head(1)
# Out:
#     age gender             educationLevel       incomeLevel bitcoinAwareness  \
# 0  1994   Male  Master's degree and above  50,000 to 99,999              Yes
#
#             vote  reasonsForVote  freeFromGov pricingByMajorOwners  \
# 0  I am not sure             NaN  Very likely              Neutral
#
#       scarcity noIntrinsicValue paymentConvenience riskyDigitWallet  \
# 0  Very likely    Very unlikely           Unlikely         Unlikely
#
#   freelyTraded fraudTendency lowTransactionFee costyMining
# 0  Very likely      Unlikely     Very unlikely      Likely

# %% [markdown]
# ##### Converting column value year of birth to age

# %%
# check & clean the abnormal inputs in age column
for i in df.age:
    if str.isnumeric(i):
        pass
    else: 
        print(i)
# Out:
# 20 Aug 1975
# 18 Jun 1977
# 5/Feb/1992
# 25 November 1990
# December 24, 1985
# 18/10

# %% [raw]
# Remove extra information on date and month of birth by replacing with year only; Drop input '18/10' as unable to identify true value.

# %%
dictAge = {'20 Aug 1975':'1975', '18 Jun 1977':'1977', '5/Feb/1992':'1992','25 November 1990':'1990',\
           'December 24, 1985':'1985'  }
df.age.replace(to_replace=dictAge, inplace=True)
df = df.drop(df[df.age=='18/10'].index)

# %%
df.age = pd.to_numeric(df.age).astype('int')

# %%
 df = df.assign(age = lambda x: (2022-x['age']))

# %%
df.age.describe()
# Out:
# count    70.000000
# mean     40.242857
# std       8.990229
# min      25.000000
# 25%      32.000000
# 50%      39.000000
# 75%      47.000000
# max      63.000000
# Name: age, dtype: float64

# %% [markdown]
# ##### Drop column 'reasonForVote' as there is no value inside

# %%
df = df.drop('reasonsForVote', axis=1)

# %% [markdown]
# ##### Converting object type columns to categorical type

# %%
df.columns
# Out:
# Index(['age', 'gender', 'educationLevel', 'incomeLevel', 'bitcoinAwareness',
#        'vote', 'freeFromGov', 'pricingByMajorOwners', 'scarcity',
#        'noIntrinsicValue', 'paymentConvenience', 'riskyDigitWallet',
#        'freelyTraded', 'fraudTendency', 'lowTransactionFee', 'costyMining'],
#       dtype='object')

# %%
Cat_features = ['gender', 'educationLevel', 'incomeLevel', 'bitcoinAwareness', 'vote', 'freeFromGov', \
                'pricingByMajorOwners', 'scarcity', 'noIntrinsicValue', 'paymentConvenience', 'riskyDigitWallet',\
                'freelyTraded', 'fraudTendency', 'lowTransactionFee', 'costyMining']

# %%
df[Cat_features] = df[Cat_features].astype('category')

# %% [markdown]
# ##### Pre-processed data summary
#
# An overview on the data can help us understand how well the sample could represent the population and understand the possible tendencies in granting Bitcoin as legal tender, if any.

# %%
df.head(1)
# Out:
#    age gender             educationLevel       incomeLevel bitcoinAwareness  \
# 0   28   Male  Master's degree and above  50,000 to 99,999              Yes
#
#             vote  freeFromGov pricingByMajorOwners     scarcity  \
# 0  I am not sure  Very likely              Neutral  Very likely
#
#   noIntrinsicValue paymentConvenience riskyDigitWallet freelyTraded  \
# 0    Very unlikely           Unlikely         Unlikely  Very likely
#
#   fraudTendency lowTransactionFee costyMining
# 0      Unlikely     Very unlikely      Likely

# %%
df.tail(1)
# Out:
#     age gender     educationLevel       incomeLevel bitcoinAwareness  \
# 70   47   Male  Bachelor's degree  50,000 to 99,999              Yes
#
#              vote freeFromGov pricingByMajorOwners scarcity noIntrinsicValue  \
# 70  I am not sure      Likely          Very likely   Likely           Likely
#
#    paymentConvenience riskyDigitWallet   freelyTraded fraudTendency  \
# 70           Unlikely           Likely  Very unlikely   Very likely
#
#    lowTransactionFee  costyMining
# 70           Neutral  Very likely

# %%
df.shape
# Out:
# (70, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 70 entries, 0 to 70
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   age                   70 non-null     int32
#  1   gender                70 non-null     category
#  2   educationLevel        70 non-null     category
#  3   incomeLevel           70 non-null     category
#  4   bitcoinAwareness      70 non-null     category
#  5   vote                  70 non-null     category
#  6   freeFromGov           70 non-null     category
#  7   pricingByMajorOwners  70 non-null     category
#  8   scarcity              70 non-null     category
#  9   noIntrinsicValue      70 non-null     category
#  10  paymentConvenience    70 non-null     category
#  11  riskyDigitWallet      70 non-null     category
#  12  freelyTraded          70 non-null     category
#  13  fraudTendency         70 non-null     category
# ...

# %% [markdown]
# There are seventy observations with one numerical feature('age') and 15 categorical features

# %% [markdown]
# #### Voting status

# %%
# overall voting staus
df.vote.value_counts()
# Out:
# I am not sure                                      30
# No, I am against it                                25
# Yes, I support to grant Bitcoin as legal tender    15
# Name: vote, dtype: int64

# %% [markdown]
# Based on participants stances, this report will refer participants voted "I am not sure" as neutral or neutral voters, participants voted "No, I am against it" as againsters and participants voted "Yes, I support to grant Bitcoin as legal tender" as supporters.
# Thirty participants are neutral, twenty five are againsters and fifteen are supporters.

# %% [markdown]
# #### What are people's backgrounds?
#
# Does the sample normally distributed? Do people's backgrounds influence their attitudes to Bitcoin?

# %%
df.describe()
# Out:
#              age
# count  70.000000
# mean   40.242857
# std     8.990229
# min    25.000000
# 25%    32.000000
# 50%    39.000000
# 75%    47.000000
# max    63.000000

# %% [markdown]
# The age ranged from 25 to 63 years old, with mean around 40 years old, median 39 years old and standdeviation around 9years.

# %%
df[['gender', 'educationLevel', 'incomeLevel', 'bitcoinAwareness']].describe()
# Out:
#        gender     educationLevel       incomeLevel bitcoinAwareness
# count      70                 70                70               70
# unique      2                  3                 5                2
# top      Male  Bachelor's degree  50,000 to 99,999              Yes
# freq       41                 38                29               60

# %%
len(Cat_features)
# Out:
# 15

# %% [markdown]
# For the fifteen categorical features, three of which related to participants backgroud, one related bitcoin awareness and one for voting status. The remaining ten of which described bitcoin features. While Out of seventy participants, the most frequent count for each feature including forty-one males, thirty-eight bachelor's degree holders, twenty-nine with income level of 50,000 to 99,000 USD annually. Additionally, sixty participants knew bitcoin when attending survey.

# %%
# voting by age
df.groupby('vote').agg(['min', 'max', 'mean', 'std', 'median'])
# Out:
#                                                 age                            \
#                                                 min max       mean        std
# vote
# I am not sure                                    25  57  38.766667   7.890122
# No, I am against it                              27  56  41.760000   9.417537
# Yes, I support to grant Bitcoin as legal tender  30  63  40.666667  10.410617
#
#
#                                                 median
# vote
# I am not sure                                     39.0
# No, I am against it                               42.0
# Yes, I support to grant Bitcoin as legal tender   38.0

# %% [markdown]
# The age of againsters are smallest in range,from 27 to 56 years old, with highest mean and median value. They tend to gether around slightly higher age level. While the supporters are most dispersed in age by looking at the age range and stand deviation. supporters have the oldest participant. On the contrary, the neutral have the youngest voter and smallest standard deviation, which means they are more concentrated around the mean age.

# %%
# voting by gender
pd.crosstab(df.vote, df.gender, margins=True)
# Out:
# gender                                           Female  Male  All
# vote
# I am not sure                                        15    15   30
# No, I am against it                                   9    16   25
# Yes, I support to grant Bitcoin as legal tender       5    10   15
# All                                                  29    41   70

# %% [markdown]
# Both male and female voters have the same number of neutrals while the number of male againsters and supporters are around twice as much as of female.

# %%
# voting by income level
pd.crosstab(df.vote, df.incomeLevel, margins=True)
# Out:
# incomeLevel                                      100,000 and above  \
# vote
# I am not sure                                                    2
# No, I am against it                                              3
# Yes, I support to grant Bitcoin as legal tender                  0
# All                                                              5
#
# incomeLevel                                      30,000 to 49,999  \
# vote
# I am not sure                                                   5
# No, I am against it                                             5
# Yes, I support to grant Bitcoin as legal tender                 4
# All                                                            14
#
# incomeLevel                                      50,000 to 99,999  \
# vote
# I am not sure                                                  11
# No, I am against it                                            11
# Yes, I support to grant Bitcoin as legal tender                 7
# ...

# %% [markdown]
# Most voters gathered in the annual income level of 50,000 to 99,999 USD, followed by income level of 30,000 to 49,999. Few voters earn more than USD100,000 annually. Regardles income level, most voters are neutrals or againsters.

# %%
# voting by education level
pd.crosstab(df.vote, df.educationLevel, margins=True)
# Out:
# educationLevel                                   Bachelor's degree  \
# vote
# I am not sure                                                   18
# No, I am against it                                             12
# Yes, I support to grant Bitcoin as legal tender                  8
# All                                                             38
#
# educationLevel                                   Diploma and below  \
# vote
# I am not sure                                                    3
# No, I am against it                                              0
# Yes, I support to grant Bitcoin as legal tender                  2
# All                                                              5
#
# educationLevel                                   Master's degree and above  \
# vote
# I am not sure                                                            9
# No, I am against it                                                     13
# ...

# %% [markdown]
# Voters are mostly holding bachelor's degree. Most of them are neutral, least are supporters. Voters holding Master's degree and above have a highest propotion of againsters while the voters holding Diploma degree or below do not have any againsters.

# %%
df.groupby([ 'gender','educationLevel']).agg(['count','min','max', 'mean','median'])
# Out:
#                                    age
#                                  count min max       mean median
# gender educationLevel
# Female Bachelor's degree            15  27  47  34.400000   32.0
#        Diploma and below             1  57  57  57.000000   57.0
#        Master's degree and above    13  25  54  44.307692   44.0
# Male   Bachelor's degree            23  28  56  38.434783   37.0
#        Diploma and below             4  30  63  43.750000   41.0
#        Master's degree and above    14  28  57  43.500000   45.0

# %% [markdown]
# Voters are holding Bachelor's degree tend to have a younger mean and median age than those holding Master's degree and above in both gender groups.

# %%
df.groupby([ 'gender','incomeLevel']).agg(['count','min','max', 'mean','median'])
# Out:
#                            age
#                          count min max       mean median
# gender incomeLevel
# Female 100,000 and above     2  32  39  35.500000   35.5
#        30,000 to 49,999      6  27  44  34.000000   33.0
#        50,000 to 99,999      9  31  54  44.333333   42.0
#        below 30,000          5  31  52  37.600000   35.0
#        prefer not to say     7  25  57  41.000000   42.0
# Male   100,000 and above     3  44  53  49.000000   50.0
#        30,000 to 49,999      8  30  63  37.750000   35.5
#        50,000 to 99,999     20  28  57  39.650000   41.0
#        below 30,000          3  30  56  40.000000   34.0
#        prefer not to say     7  28  53  43.714286   45.0

# %% [markdown]
# Most frequent voters are from income level of 50,000 to 99,999 with a age median value just over forty for both male and female
#
# Diploma education level and below tends had lower income level for both male and female regardless of age. Most male salary level are between 50,000 and 99,000 USD annually for Bachelor's degree and above with the mean and median age around 40. The same tendency could be seen for female holding Master's degree and above but with higher mean and median age around late forties. Females holding Bachelor's degree tend to have dispersed distribution in salary level with the most frequent number in annual salary level from 30,000 to 49,999 USD.

# %% [markdown]
# The demographic of sample showed a central tendency of mean age around 40, most frequent income level of 50,000 to 99,999, most frequent education level of Bachelor's degree and a roughly balanced gender distribution. This is acceptable in representing population as this project only targeted at the Enligsh speakers. A good grasp of English usually comes along with higher education especially for countries speaking different languages.  Data showed that higher education and income level tends to encourage againters. While female showed a tendency to be neutral

# %% [markdown]
# #### How Bitcoin’s features influence people’s attitude to Bitcoin?

# %%
BC_features = ['freeFromGov', 'pricingByMajorOwners', 'scarcity','noIntrinsicValue', 'paymentConvenience',\
               'riskyDigitWallet','freelyTraded', 'fraudTendency', 'lowTransactionFee','costyMining']

# %%
len(BC_features)
# Out:
# 10

# %%
df[BC_features].describe()
# Out:
#        freeFromGov pricingByMajorOwners scarcity noIntrinsicValue  \
# count           70                   70       70               70
# unique           5                    5        5                5
# top        Neutral               Likely  Neutral      Very likely
# freq            21                   26       25               19
#
#        paymentConvenience riskyDigitWallet freelyTraded fraudTendency  \
# count                  70               70           70            70
# unique                  5                5            5             5
# top               Neutral           Likely      Neutral   Very likely
# freq                   27               20           25            25
#
#        lowTransactionFee  costyMining
# count                 70           70
# unique                 5            5
# top              Neutral  Very likely
# freq                  32           26

# %% [markdown]
# There are ten bitcoin features investigated by this survey project. Participants were required to evaluate how each of the feature contribute to their voting decision by a five level likert scale, namely 'Very likely', 'Likely', 'Neutral', 'Unlikely' and 'Very unlikely'. For those participants selected a feature 'Neutral' contribution to their vote, this survey will refer the feature as "irrelevant" feature, which could also be explained as unimportant to one's choice.

# %% [markdown]
# Out of 10 bitcoin features, more participants believed that 'freeFromGov', 'Scarcity', 'paymentConvenience', 'freelyTraded' and 'lowTransactionFee' were irrelevant to their vote. While other features are more likely contributed to the votes.

# %% [markdown]
# ## Analysis and results
#
# It is important to understand each feature and its impact on voting, explore the correlation among features and find out how each feature influenced voters choices.

# %% [markdown]
# #### Sample group demographic analysis

# %%
# define color scheme for different voting stances

Stance = {'I am not sure':'#808080', 'No, I am against it':'#dd8452', 'Yes, I support to grant Bitcoin as legal tender':'#55a868'}

# %%
# age distribution by boxplot

sns.set_theme(style="darkgrid")
ax = sns.boxplot(x=df["age"])
plt.legend(["Mean is {:.0f}".format(df.age.mean()) , "Mediam is {:.0f}".format(df.age.median()), \
            "Mode is {:.0f}".format(df.age.mode()[0])])
plt.title('Distribution of Age')
plt.show()

# %%
# age distribution by histogram

sns.set_theme(style="darkgrid")
ax = sns.distplot(x=df["age"])
plt.legend(["Skewness is {:.1f}".format(df.age.skew()) , "Kurtosis is {:.1f}".format(df.age.kurt())])
plt.title('Distribution of Age')
plt.show()

# %% [markdown]
# The age ranged 25 to 63, close to normal distribution with mean value at 40 years old, median at 39 years old and most frequent age at 42 year old.

# %%
ax = sns.catplot(x='age', y='vote', data=df, kind='box', palette=Stance)
plt.xticks(rotation=0)
plt.title('Age distribution to votes')
plt.show()

# %% [markdown]
# Neutral voters are left skewed while supporters are right skewed in age distribution. In the contrary, againsters have good symmetry in age distribution and close to normally distribution. The IQR(interquartile range,is a measure of statistical dispersion) for againsters is biggest, followed  by supporters. Neutral voters IQR is the narrowest while the range(minimum age to maximum age) for againsters is the smallest.

# %%
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="gender", data=df, order=['Female', 'Male'])
plt.title('Distribution of Gender')
for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.3, p.get_height()+0.3))
plt.show()

# %% [markdown]
# There are more male than female.

# %%
ct = pd.crosstab(df["gender"],df["vote"])
ax = ct.plot.bar(stacked=False, color=Stance)
plt.xticks(rotation = 0)
ax.set_xlabel("")
plt.title('"gender" distribution against vote')
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')
for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.05, p.get_height()+0.03))
plt.show()

# %%
ct = pd.crosstab(df["gender"], df["vote"], normalize='index').round(2)
ax = ct.plot.bar(stacked=True, color=Stance)

plt.title('"gender" distribution against vote')
plt.xticks(rotation = 10)
ax.set_xlabel("")
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')

for c in ax.containers:
    labels = [p.get_height() if p.get_height() > 0 else " " for p in c]
    ax.bar_label(c, label_type='center', label=labels)
plt.show()

# %%
ct = pd.crosstab(df["vote"], df["gender"], normalize='all').round(2)
ax = ct.plot.bar(stacked=True)

plt.title('"gender" distribution against vote')
plt.xticks(rotation = 10)
ax.set_xlabel("")
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')

for c in ax.containers:
    labels = [p.get_height() if p.get_height() > 0 else " " for p in c]
    ax.bar_label(c, label_type='center', label=labels)
plt.show()

# %% [markdown]
# Most female tend to take neutral position, while most male positioned themself against Bitcoin. It seems that female tends to take neutral position than male.

# %%
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="educationLevel", data=df)
plt.xticks(rotation=10)
ax.set_xlabel("")
plt.title('Distribution of Education Level')
for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.3, p.get_height()+0.3))
plt.show()

# %% [markdown]
# Most people in the sample group have a Bachelors degree, followed by Master's degree or above. Few people only have Diploma degree or below

# %%
ct = pd.crosstab(df["educationLevel"],df["vote"])
ax = ct.plot.bar(stacked=False, color=Stance)
plt.xticks(rotation = 10)
ax.set_xlabel("")
plt.title('"educationLevel" distribution against vote')
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')
for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.05, p.get_height()+0.03))
plt.show()

# %%
ct = pd.crosstab(df["educationLevel"], df["vote"], normalize='index').round(2)
ax = ct.plot.bar(stacked=True, color=Stance)

plt.title('"educationLevel" distribution against vote')
plt.xticks(rotation = 10)
ax.set_xlabel("")
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')

for c in ax.containers:
    labels = [p.get_height() if p.get_height() > 0 else " " for p in c]
    ax.bar_label(c, label_type='center', label=labels)
plt.show()

# %%
ct = pd.crosstab(df["vote"], df["educationLevel"], normalize='all').round(2)
ax = ct.plot.bar(stacked=True)

plt.title('"educationLevel" distribution against vote')
plt.xticks(rotation = 10)
ax.set_xlabel("")
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')

for c in ax.containers:
    labels = [p.get_height() if p.get_height() > 0 else " " for p in c]
    ax.bar_label(c, label_type='center', label=labels)
plt.show()

# %% [markdown]
# The graphs show that the lower the education level, the higher supporting rate. When the educational level increases, the againsting rate also increases.

# %%
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="incomeLevel", data=df, order=['100,000 and above','30,000 to 49,999','50,000 to 99,999','below 30,000', 'prefer not to say'] )
plt.xticks(rotation=10)
ax.set_xlabel("")
plt.title('Distribution of Annual Income Level in USD')
for p in ax.patches:
    ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.3, p.get_height()+0.3))
plt.show()

# %% [markdown]
# Most people are in the middle income group, namely from 30,000 to 49,999 and from 50,000 to 99,999. While the counts in the higher end of middle income group almost twice as much as lower counter part. There are considerate people do not wish to reveal their income information. Less people own income less than 30,000 however the counts are more than income level of 100,000 and above.

# %%
ct = pd.crosstab(df["incomeLevel"], df["vote"]).round(2)
ax = ct.plot.bar(stacked=False, color=Stance, )

plt.title('"incomeLevel" distribution to vote')
plt.xticks(rotation = 10)
ax.set_xlabel("")
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')
for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.01, p.get_height()+0.03))
plt.show()

# %% [markdown]
# the number of neutral voters is the same as the againsters in the income groups from 30,000 up to 99,999. Most fo the participants who did not wish to reveal their income level are neutral.

# %%
ct = pd.crosstab(df["incomeLevel"], df["vote"], normalize='index').round(2)
ax = ct.plot.bar(stacked=True, color=Stance, )

plt.title('"incomeLevel" distribution to vote')
plt.xticks(rotation = 10)
ax.set_xlabel("")
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')

for c in ax.containers:
    labels = [p.get_height() if p.get_height() > 0 else " " for p in c]
    ax.bar_label(c, label_type='center', label=labels)
plt.show()

# %%
ct = pd.crosstab(df["vote"], df["incomeLevel"], normalize='all').round(2)
ax = ct.plot.bar(stacked=True )

plt.title('"incomeLevel" distribution to vote')
plt.xticks(rotation = 10)
ax.set_xlabel("")
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')

for c in ax.containers:
    labels = [p.get_height() if p.get_height() > 0 else " " for p in c]
    ax.bar_label(c, label_type='center', label=labels)
plt.show()

# %% [markdown]
# There is a significant neutral voters in each of the income group. The againster's rates steadily grows with income level. No supporters is shown in the income level 100,000USD and above.

# %% [markdown]
# In brief, the sample group has an acceptable extend of normal distribution with the mean, median, mode age value around forty, held Bachelor's degree and earned thirty-thousand to a hundred-thousand US dollars annually.

# %% [markdown]
# #### Bitcoin Awareness: Do you know Bitcoin?

# %%
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="bitcoinAwareness", data=df, order=['No', 'Yes'])
plt.title('Distribution of bitcoinAwareness')
for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.3, p.get_height()+0.3))
plt.show()

# %% [markdown]
# Upon seventy samples, sixty know Bitcoin and 10 do not know Bitcoin

# %%
ct = pd.crosstab(df["bitcoinAwareness"], df["vote"]).round(2)
ax = ct.plot.bar(stacked=False, color=Stance, )

plt.title('"bitcoinAwareness" distribution to vote')
plt.xticks(rotation = 0)
ax.set_xlabel("")
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')
for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.05, p.get_height()+0.03))
plt.show()

# %%
ct = pd.crosstab(df["bitcoinAwareness"], df["vote"], normalize='all').round(2)
ax = ct.plot.bar(stacked=True, color=Stance)

plt.title('"bitcoinAwareness" distribution against vote')
plt.xticks(rotation = 0)
ax.set_xlabel("")
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')
labels = [p.get_height() if p.get_height() > 0 else " " for p in c]
for c in ax.containers:
    labels = [p.get_height() if p.get_height() > 0 else " " for p in c]
    ax.bar_label(c, label_type='center', label=labels)
plt.show()

# %%
ct = pd.crosstab(df["bitcoinAwareness"], df["vote"], normalize='index').round(2)
ax = ct.plot.bar(stacked=True, color=Stance)

plt.title('"bitcoinAwareness" distribution against vote')
plt.xticks(rotation = 0)
ax.set_xlabel("")
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')

for c in ax.containers:
    labels = [p.get_height() if p.get_height() > 0 else " " for p in c]
    ax.bar_label(c, label_type='center', label=labels)
plt.show()

# %% [markdown]
# Participants who do not know bitcoin showed uncertainty or rejection to bitcoin as legal tender. While those who knows bitcoin also showed high uncertainty or rejective to bitcoin as legal tender. Only 25% of participants who said known Bitcoin supported to grant Bitcoin as legal tender.

# %% [markdown]
# Overall, there is more symetric in againsters age distribution. Female showed a more neutral tendency than male voters. Moreover, the proportion of againsters steadily increased when the income level or education level increased. Lastly, voters who did not know Bitcoin are unlikely to support it as legal tender.

# %% [markdown]
# #### Voting: Do you support or against to grant Bitcoin as legal tender in your country?

# %%
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="vote", data=df, palette=Stance)
plt.title('Voting status for Bitcoin as legal tender')
plt.xticks(rotation=10)
for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.3, p.get_height()+0.3))
plt.show()

# %%
S = ['#808080','#dd8452','#55a868']
Vote = df["vote"].value_counts()
labels = ['I am not sure','No, I am against it','Yes, I support to grant Bitcoin as legal tender']

sns.set_palette(sns.color_palette(S))

plt.pie(Vote, labels=labels, colors = S, autopct = '%0.0f%%', radius=1)
plt.title('Bitcoin voting status by percentage')
plt.show()

# %% [markdown]
# Thirty out of seventy people(43%) are not sure to support Bitcoin as legal tender. Twenty-five(36%) people are against it. Only ten(21%) out of seventy support Bitcoin as legal tender.

# %% [markdown]
# #### Analysis on Bitcoin features: How likely do the below Bitcoin features contribute to your stance of support or against to grant bitcoin as legal tender?
#
# Each participant were requested to selected from a Likert scale on each of the ten Bitcoin features. Ten feature comparisons based on the voter groups including, total voters, neutral voters, supporters, againsters were made to understand the tendencies inside each voter group. After that, detailed analysises were made on each of the feature to understand how it contribute to different voter groups.
#
# The likert scale will be discussed as three categories, namely likely/verylikely, neutral, unlikely/very unlikely. When voters chose neutral in the likert scale, it will bereferred as irrelevant or unimportant of this feature.

# %%
df[BC_features].head(1)
# Out:
#    freeFromGov pricingByMajorOwners     scarcity noIntrinsicValue  \
# 0  Very likely              Neutral  Very likely    Very unlikely
#
#   paymentConvenience riskyDigitWallet freelyTraded fraudTendency  \
# 0           Unlikely         Unlikely  Very likely      Unlikely
#
#   lowTransactionFee costyMining
# 0     Very unlikely      Likely

# %%
# define colors for likert scale
 
colors = {"Very unlikely": '#d95847', "Unlikely": "#f18d6f", "Neutral":"grey",\
          "Likely":"#aac7fd", "Very likely":"#82a6fb"}

# %%
# Overview for features likert scale rating for all observations. 

plt.figure(figsize=(20,22))
i=1

for col in BC_features:
    plt.subplot(4,3,i)
    i = i + 1
    ax = sns.countplot(x=col, data=df, palette=colors, order=['Very likely', 'Likely', 'Neutral', 'Unlikely', 'Very unlikely'])
    sns.set(font_scale = 1.2)
    plt.title('{} contributes to my stance'.format(col))
    plt.xticks(rotation=0)
    ax.set_xlabel("")
    for p in ax.patches:
        ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.3, p.get_height()+0.1))

# %% [markdown]
# Features of 'freeFromGov', 'Scarcity', 'paymentConvenience', 'freelyTraded' and 'lowTransactionFee' are highly selected(more than 30% of total counts) as unimportant or irrelevant to the votes. Other features are considered more likely to contribute to the votes.

# %%
# Overview for features likert scale rating for neutral voters

Neutral = df[df['vote']=='I am not sure']

plt.figure(figsize=(20,22))
i=1

for col in BC_features:
    plt.subplot(4,3,i)
    i = i + 1
    ax = sns.countplot(x=col, data=Neutral, palette=colors, order=['Very likely', 'Likely', 'Neutral', 'Unlikely', 'Very unlikely'])
    sns.set(font_scale = 1.2)
    plt.title('{} contributes to my neutral stance'.format(col))
    plt.xticks(rotation=0)
    ax.set_xlabel("")
    for p in ax.patches:
        ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.3, p.get_height()+0.1))

# %%
print(len(Neutral))
print( len(df))
# Out:
# 30
# 70

# %% [markdown]
# Thirty out of seventy participants had a neutral stance.
#
# The features of 'freeFromGov', 'Scarcity', 'paymentConvenience','freelyTraded' and 'lowTranscationFee' are significantly considered as unimportant to neutral voters. While the number of voters who believed that features 'noIntrinsicValue'and 'riskyDigitWallet' were unimportant is almost equivalent to those, who believed these features unlikely or very unlikely contribute to their votes.
#
# Each feature was chosen as unimportant by considerable voters, while more voters selected these features likely or very likely contributed to their votes.

# %%
# Overview for features likert scale rating for supporters. 
supporter = df[df['vote']=='Yes, I support to grant Bitcoin as legal tender']

plt.figure(figsize=(20,22))
i=1

for col in BC_features:
    plt.subplot(4,3,i)
    i = i + 1
    ax = sns.countplot(x=col, data=supporter, palette=colors, order=['Very likely', 'Likely', 'Neutral', 'Unlikely', 'Very unlikely'])
    sns.set(font_scale = 1.2)
    plt.title('{} makes me support Bitcoin'.format(col))
    plt.xticks(rotation=0)
    ax.set_xlabel("")
    for p in ax.patches:
        ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.3, p.get_height()+0.1))

# %%
print(len(supporter))
print( len(df))
# Out:
# 15
# 70

# %% [markdown]
# Fifteen out of seventy participants are supporters.
#
# For each of the features listed, more supporters vetted it as likely or very likely to contribute to their choice, while a considerable number of supporters vetted each feature as unimportant or irrelevant except feature of 'pricingByMajorOwners'. Only one supporter vetted it irrelevant. Incredibly, almost none of the supporters vetted features of 'Scarcity', 'paymentConvenience', 'fraudTendency', 'lowTranscationFee', 'freelyTraded' and 'costyMining' as unlikely or very unlikely contributing to their support.

# %%
# Overview for features likert scale rating for againsters. 

againster = df[df['vote']=='No, I am against it']

plt.figure(figsize=(20,22))
i=1

for col in BC_features:
    plt.subplot(4,3,i)
    i = i + 1
    ax = sns.countplot(x=col, data=againster, palette=colors, order=['Very likely', 'Likely', 'Neutral', 'Unlikely', 'Very unlikely'])
    sns.set(font_scale = 1.2)
    plt.title('{} makes me against Bitcoin'.format(col))
    plt.xticks(rotation=0)
    ax.set_xlabel("")
    for p in ax.patches:
        ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.3, p.get_height()+0.1))

# %%
print(len(againster))
print( len(df))
# Out:
# 25
# 70

# %% [markdown]
# Twenty-five out of seventy participants is againsters.
#
# Most againsters vetted features 'freeFromGov' and 'paymentConvenience' unlikely or very unlikely contributing to their choices while features 'freelyTraded' and 'lowTransactionFee' are irrelevant to their choices. Moreover, considerable amount of againsters think 'freeFromGov', 'pricingByMajorOwners','Scarcity','paymentConvenience', 'riskyDigiWallet' are irrelevant to their choice.  In contrast, most againsters vetted 'pricingByMajorOwners', 'Scarcity', 'noIntrinsicValue', 'riskyDigitWallet','fraudTendency'and 'costyMining' as likely or very likely contributing to their votes.

# %% [markdown]
# ### Likert scale distribution at each Bitcoin feature level

# %%
ct = pd.crosstab( df["vote"], df["freeFromGov"])
ax = ct.plot.bar(stacked=False, color=colors)
plt.xticks(rotation = 10)
ax.set_xlabel("")
plt.title('"freeFromGov" contributes to my vote')
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')
for p in ax.patches:
    ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.01, p.get_height()+0.03))
plt.show()

# %%
ct = pd.crosstab(df["vote"], df["freeFromGov"], normalize='all').round(2)
ax = ct.plot.bar(stacked=True,color=colors)

plt.title('"freeFromGov" contributes to my vote')
plt.xticks(rotation = 10)
ax.set_xlabel("")
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')
labels = [p.get_height() if p.get_height() > 0 else " " for p in c]
for c in ax.containers:
    labels = [p.get_height() if p.get_height() > 0 else " " for p in c]
    ax.bar_label(c, label_type='center', label=labels)
plt.show()

# %%
ct = pd.crosstab(df["vote"], df["freeFromGov"], normalize='index').round(2)
ax = ct.plot.bar(stacked=True,color=colors)

plt.title('"freeFromGov" contributes to my vote')
plt.xticks(rotation = 10)
ax.set_xlabel("")
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')
labels = [p.get_height() if p.get_height() > 0 else " " for p in c]
for c in ax.containers:
    labels = [p.get_height() if p.get_height() > 0 else " " for p in c]
    ax.bar_label(c, label_type='center', label=labels)
plt.show()

# %%
ct = pd.crosstab( df["vote"], df["pricingByMajorOwners"],)
ax = ct.plot.bar(stacked=False, color=colors)
plt.xticks(rotation = 10)
ax.set_xlabel("")
plt.title('pricingByMajorOwners contributes to my vote')
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')
for p in ax.patches:
    ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.01, p.get_height()+0.03))
plt.show()

# %%
ct = pd.crosstab(df["vote"], df["pricingByMajorOwners"], normalize='all').round(2)
ax = ct.plot.bar(stacked=True,color=colors)

plt.title('pricingByMajorOwners contributes to my vote')
plt.xticks(rotation = 10)
ax.set_xlabel("")
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')
labels = [p.get_height() if p.get_height() > 0 else " " for p in c]
for c in ax.containers:
    labels = [p.get_height() if p.get_height() > 0 else " " for p in c]
    ax.bar_label(c, label_type='center', label=labels)
plt.show()

# %%
ct = pd.crosstab(df["vote"], df["pricingByMajorOwners"], normalize='index').round(2)
ax = ct.plot.bar(stacked=True,color=colors)

plt.title('pricingByMajorOwners contributes to my vote')
plt.xticks(rotation = 10)
ax.set_xlabel("")
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')
labels = [p.get_height() if p.get_height() > 0 else " " for p in c]
for c in ax.containers:
    labels = [p.get_height() if p.get_height() > 0 else " " for p in c]
    ax.bar_label(c, label_type='center', label=labels)
plt.show()

# %%
ct = pd.crosstab(df["vote"], df["scarcity"])
ax = ct.plot.bar(stacked=False,color=colors)
plt.xticks(rotation = 10)
ax.set_xlabel("")
plt.title('"scarcity" contributes to my vote')
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')
for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.01, p.get_height()+0.03))
plt.show()

# %%
ct = pd.crosstab(df["vote"], df["scarcity"], normalize='all').round(2)
ax = ct.plot.bar(stacked=True,color=colors)

plt.title('"scarcity" contributes to my vote')
plt.xticks(rotation = 10)
ax.set_xlabel("")
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')

for c in ax.containers:
    labels = [p.get_height() if p.get_height() > 0 else " " for p in c]
    ax.bar_label(c, label_type='center', label=labels)
plt.show()

# %%
ct = pd.crosstab(df["vote"], df["scarcity"], normalize='index').round(2)
ax = ct.plot.bar(stacked=True,color=colors)

plt.title('"scarcity" contributes to my vote')
plt.xticks(rotation = 10)
ax.set_xlabel("")
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')

for c in ax.containers:
    labels = [p.get_height() if p.get_height() > 0 else " " for p in c]
    ax.bar_label(c, label_type='center', label=labels)
plt.show()

# %%
ct = pd.crosstab( df["vote"], df["noIntrinsicValue"],)
ax = ct.plot.bar(stacked=False, color=colors)
plt.xticks(rotation = 10)
ax.set_xlabel("")
plt.title('"noIntrinsicValue" contributes to my vote')
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')
for p in ax.patches:
    ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.01, p.get_height()+0.03))
plt.show()

# %%
ct = pd.crosstab(df["vote"], df["noIntrinsicValue"], normalize='all').round(2)
ax = ct.plot.bar(stacked=True,color=colors)

plt.title('"noIntrinsicValue" contributes to my vote')
plt.xticks(rotation = 10)
ax.set_xlabel("")
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')

for c in ax.containers:
    labels = [p.get_height() if p.get_height() > 0 else " " for p in c]
    ax.bar_label(c, label_type='center', label=labels)
plt.show()

# %%
ct = pd.crosstab(df["vote"], df["noIntrinsicValue"], normalize='index').round(2)
ax = ct.plot.bar(stacked=True,color=colors)

plt.title('"noIntrinsicValue" contributes to my vote')
plt.xticks(rotation = 10)
ax.set_xlabel("")
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')

for c in ax.containers:
    labels = [p.get_height() if p.get_height() > 0 else " " for p in c]
    ax.bar_label(c, label_type='center', label=labels)
plt.show()

# %%
ct = pd.crosstab(df["vote"], df["paymentConvenience"])
ax = ct.plot.bar(stacked=False, color=colors)
plt.xticks(rotation = 10)
ax.set_xlabel("")
plt.title('paymentConvenience contributes to my vote')
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')
for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.01, p.get_height()+0.03))
plt.show()

# %%
ct = pd.crosstab(df["vote"], df["paymentConvenience"], normalize='all').round(2)
ax = ct.plot.bar(stacked=True,color=colors)

plt.title('"paymentConvenience" contributes to my vote')
plt.xticks(rotation = 10)
ax.set_xlabel("")
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')

for c in ax.containers:
    labels = [p.get_height() if p.get_height() > 0 else " " for p in c]
    ax.bar_label(c, label_type='center', label=labels)
plt.show()

# %%
ct = pd.crosstab(df["vote"], df["paymentConvenience"], normalize='index').round(2)
ax = ct.plot.bar(stacked=True,color=colors)

plt.title('"paymentConvenience" contributes to my vote')
plt.xticks(rotation = 10)
ax.set_xlabel("")
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')

for c in ax.containers:
    labels = [p.get_height() if p.get_height() > 0 else " " for p in c]
    ax.bar_label(c, label_type='center', label=labels)
plt.show()

# %%
ct = pd.crosstab(df["vote"], df["riskyDigitWallet"])
ax = ct.plot.bar(stacked=False, color=colors)
plt.xticks(rotation = 10)
ax.set_xlabel("")
plt.title('riskyDigitWallet contributes to my vote')
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')
for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.01, p.get_height()+0.03))
plt.show()

# %%
ct = pd.crosstab(df["vote"], df["riskyDigitWallet"], normalize='all').round(2)
ax = ct.plot.bar(stacked=True,color=colors)

plt.title('"riskyDigitWallet" contributes to my vote')
plt.xticks(rotation = 10)
ax.set_xlabel("")
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')

for c in ax.containers:
    labels = [p.get_height() if p.get_height() > 0 else " " for p in c]
    ax.bar_label(c, label_type='center', label=labels)
plt.show()

# %%
ct = pd.crosstab(df["vote"], df["riskyDigitWallet"], normalize='index').round(2)
ax = ct.plot.bar(stacked=True,color=colors)

plt.title('"riskyDigitWallet" contributes to my vote')
plt.xticks(rotation = 10)
ax.set_xlabel("")
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')

for c in ax.containers:
    labels = [p.get_height() if p.get_height() > 0 else " " for p in c]
    ax.bar_label(c, label_type='center', label=labels)
plt.show()

# %%
ct = pd.crosstab(df["vote"], df["freelyTraded"])
ax = ct.plot.bar(stacked=False, color=colors)
plt.xticks(rotation = 10)
ax.set_xlabel("")
plt.title('freelyTraded contributes to my vote')
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')
for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.01, p.get_height()+0.03))
plt.show()

# %%
ct = pd.crosstab(df["vote"], df["freelyTraded"], normalize='all').round(2)
ax = ct.plot.bar(stacked=True,color=colors)

plt.title('freelyTraded contributes to my vote')
plt.xticks(rotation = 10)
ax.set_xlabel("")
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')

for c in ax.containers:
    labels = [p.get_height() if p.get_height() > 0 else " " for p in c]
    ax.bar_label(c, label_type='center', label=labels)
plt.show()

# %%
ct = pd.crosstab(df["vote"], df["freelyTraded"], normalize='index').round(2)
ax = ct.plot.bar(stacked=True,color=colors)

plt.title('freelyTraded contributes to my vote')
plt.xticks(rotation = 10)
ax.set_xlabel("")
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')

for c in ax.containers:
    labels = [p.get_height() if p.get_height() > 0 else " " for p in c]
    ax.bar_label(c, label_type='center', label=labels)
plt.show()

# %%
ct = pd.crosstab(df["vote"], df["fraudTendency"])
ax = ct.plot.bar(stacked=False, color=colors)
plt.xticks(rotation = 10)
ax.set_xlabel("")
plt.title('fraudTendency contributes to my vote')
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')
for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.01, p.get_height()+0.03))
plt.show()

# %%
ct = pd.crosstab(df["vote"], df["fraudTendency"], normalize='all').round(2)
ax = ct.plot.bar(stacked=True,color=colors)

plt.title('"fraudTendency" contributes to my vote')
plt.xticks(rotation = 10)
ax.set_xlabel("")
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')

for c in ax.containers:
    labels = [p.get_height() if p.get_height() > 0 else " " for p in c]
    ax.bar_label(c, label_type='center', label=labels)
plt.show()

# %%
ct = pd.crosstab(df["vote"], df["fraudTendency"], normalize='index').round(2)
ax = ct.plot.bar(stacked=True,color=colors)

plt.title('"fraudTendency" contributes to my vote')
plt.xticks(rotation = 10)
ax.set_xlabel("")
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')

for c in ax.containers:
    labels = [p.get_height() if p.get_height() > 0 else " " for p in c]
    ax.bar_label(c, label_type='center', label=labels)
plt.show()

# %%
ct = pd.crosstab(df["vote"], df["lowTransactionFee"])
ax = ct.plot.bar(stacked=False, color=colors)
plt.xticks(rotation = 10)
ax.set_xlabel("")
plt.title('"Low transaction fee with bitcoin" contributes to my vote')
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')
for p in ax.patches:
    ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.01, p.get_height()+0.03))
plt.show()

# %%
ct = pd.crosstab(df["vote"], df["lowTransactionFee"], normalize='all').round(2)
ax = ct.plot.bar(stacked=True,color=colors)

plt.title('"lowTranscationFee" contributes to my vote')
plt.xticks(rotation = 10)
ax.set_xlabel("")
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')

for c in ax.containers:
    labels = [p.get_height() if p.get_height() > 0 else " " for p in c]
    ax.bar_label(c, label_type='center', label=labels)
plt.show()

# %%
ct = pd.crosstab(df["vote"], df["lowTransactionFee"], normalize='index').round(2)
ax = ct.plot.bar(stacked=True,color=colors)

plt.title('"lowTranscationFee" contributes to my vote')
plt.xticks(rotation = 10)
ax.set_xlabel("")
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')

for c in ax.containers:
    labels = [p.get_height() if p.get_height() > 0 else " " for p in c]
    ax.bar_label(c, label_type='center', label=labels)
plt.show()

# %%
ct = pd.crosstab(df["vote"], df["costyMining"])
ax = ct.plot.bar(stacked=False, color=colors)
plt.xticks(rotation = 10)
ax.set_xlabel("")
plt.title('"Mining bitcoin consumes heavy computing power and electricity" contributes to my vote')
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')
for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.01, p.get_height()+0.03))
plt.show()

# %%
ct = pd.crosstab(df["vote"], df["costyMining"], normalize='all').round(2)
ax = ct.plot.bar(stacked=True,color=colors)

plt.title('"costyMining" contributes to my vote')
plt.xticks(rotation = 10)
ax.set_xlabel("")
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')

for c in ax.containers:
    labels = [p.get_height() if p.get_height() > 0 else " " for p in c]
    ax.bar_label(c, label_type='center', label=labels)

plt.show()

# %%
ct = pd.crosstab(df["vote"], df["costyMining"], normalize='index').round(2)
ax = ct.plot.bar(stacked=True,color=colors)

plt.title('"costyMining" contributes to my vote')
plt.xticks(rotation = 10)
ax.set_xlabel("")
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')

for c in ax.containers:
    labels = [p.get_height() if p.get_height() > 0 else " " for p in c]
    ax.bar_label(c, label_type='center', label=labels)

plt.show()

# %% [markdown]
# How features contributes to votes
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# Overall,the features of 'freeFromGov', 'Scarcity', 'paymentConvenience','freelyTraded' and 'lowTranscationFee' are significantly selected neutrally contributed to voters (considered as unimportant to voters across different stances). The supporters showed a strong tendency to select likely/very likely for each feature. However, some features, such as costyMining, could negatively contribute to Bitcoin's value. Againters showed sensitivity to features that have a negative impact on Bitcoin's value. However, againsters had no obvious sensitivity on the features, which could be considered positive to Bitcoin's value.

# %% [markdown]
# ### Correlation among different features
#
# The above analysis explored the features of each column and the patterns between each variable, and the voting status and patterns were found. However, how are features associated with each other? Is there any feature or any pattern that significantly impact voters?

# %%
#encode categorical features with numbers.

df1 = df.drop('age', axis=1)

df1 = df1.apply(lambda x: x.cat.codes)
df1['age'] = df['age']

# %%
figure=plt.figure(figsize=[15,15])
corr=df1.corr()
sns.set(font_scale = 1)
ax = sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# If we split the association into different scales as following:
#
# 0.00 as None association
#
# 0.01 ~ 0.09 as Negligible association
#
# 0.10 ~ 0.29 as Weak association
#
# 0.30 ~ 0.59 as Moderate association
#
# 0.60 and above as strong association
#
# 1.00 as perfect association

# %% [markdown]
# Most variables pairs have negligible or weak associations while variables including "gender", "age", "incomeLeve", and "educationLevel" have negligible or weak associations to most of the variables. However, "age" variable has moderate association with "educationLevel" and "riskyDigitWallet". Further exploration was made as below to visualize the associations.
#
# On the other side, Most Bitcoin features are weakly or moderately associated with each other. This is understandable as all features reflect different aspects of Bitcoin.
#
# Overall, there is no dominant variable that strongly correlates with the votes. All variables have a weak or negligible association with the votes.

# %%
# explore association between age and education level

ax = sns.catplot(x='age', y='educationLevel', data=df, kind='box')
plt.xticks(rotation=0)
plt.title('Age distribution against "educationLevel"')
plt.show()

# %% [markdown]
# Most Bachelor's degree holders are younger than the Master's degree holder. At the same time, the Diploma's degree and below has almost the same mean value as the Master's degree holder with a broader spread of the IQR. However, such an association may be not meaningful as age is weakly associated with votes.

# %%
# explore association between age and "riskyDigitWallet"
ax = sns.catplot(x='age', y='riskyDigitWallet', data=df, kind='box', palette=colors)
plt.xticks(rotation=0)
plt.title('Age distribution against "riskyDigitWallet"')
plt.show()

# %% [markdown]
# The participants selected unlikely or very unlikely are relatively younger, while the voters chosen likely or very likely are relatively older. On the contrary, Voters who chose "Neutral" showed the widest age distribution IQR. However, such an association may be not meaningful as age is weakly associated with votes.

# %% [markdown]
# ### Pulic data on Bitcoin legal status
#
#
# Survey exploration found Bitcoin were poorly supported. however, How well is Bitcoin supported by different countries worldwide?

# %%
wikiData = pd.read_excel('wikiData.xlsx', sheet_name='Cleaned')

# %%
wikiData.head(2)
# Out:
#   Country or territory  Legality Legal status of bitcoin
# 0              Algeria   Illegal                 Hostile
# 1                Egypt   Illegal                 Hostile

# %%
wikiData.tail(3)
# Out:
#     Country or territory Legality Legal status of bitcoin
# 192              Dummies   Unknow                 No Data
# 193              Dummies   Unknow                 No Data
# 194              Dummies   Unknow                 No Data

# %%
wikiData.shape
# Out:
# (195, 3)

# %%
wikiData.describe()
# Out:
#        Country or territory Legality Legal status of bitcoin
# count                   195      195                     195
# unique                   92       13                       5
# top                 Dummies   Unknow                 No Data
# freq                    104      104                     105

# %% [markdown]
# There are 104 Countries or territories yet to be listed by Wikipedia named as 'Dummies' with the 'Legality' status as 'Unknown' and 'Legal status of bitcoin' as 'No Data'. Only one Country listed by Wikipedia has been indicated 'No data' for the 'Legal status of bitcoin' column.

# %%
wikiData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 3 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country or territory     195 non-null    object
#  1   Legality                 195 non-null    object
#  2   Legal status of bitcoin  195 non-null    object
# dtypes: object(3)
# memory usage: 4.7+ KB

# %%
wikiData['Legal status of bitcoin'].value_counts()
# Out:
# No Data         105
# Permissive       64
# Contentious      18
# Hostile           7
# Legal Tender      1
# Name: Legal status of bitcoin, dtype: int64

# %%
# visualize by number counts by bar chart
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="Legal status of bitcoin",data=wikiData, order=['Legal Tender','Permissive',\
                                                                     'Contentious','Hostile', 'No Data'])
plt.title('Bitcoin Legal status worldwide by number of countries')
ax.set_xlabel("")
for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.3, p.get_height()+0.3))
plt.show()

# %%
# visualize by percentage with pie chart.
Legal = wikiData["Legal status of bitcoin"].value_counts()
labels = ['No Data','Permissive','Contentious','Hostile','Legal Tender']

colors = sns.color_palette()
plt.pie(Legal, labels=labels,colors = colors, autopct = '%0.0f%%', radius=1)
plt.title('Bitcoin Legal status worldwide by percentage')
plt.show()

# %% [markdown]
# Compared with survey data, only around 1% of the countries grant Bitcoin as legal tender, while survey supporters estimate it to be 21%. Around 4% of the countries are hostile against Bitcoin, while survey againsters estimate it 36%. In contrast, around 95% of countries are in the middle, comparing survey neutral voter estimate as 43%. Although the number in percentage varies largely between survey data and real data, the middle position is dominant in both datasets. Moreover, there are more againsters(hostile) than supporters in both datasets. It is reasonable as granting Bitcoin as legal tender, or forbidden Bitcoin takes cautious evaluation over complex aspects. On the contrary, survey voters could disregard all these complex aspects and vote based on personal knowledge and preferences. The data suggest that the supporting rate to grant Bitcoin as legal tender is considerably low.

# %% [markdown]
# ## Conclusions
#
# The survey explored the voting status to grant Bitcoin as legal tender. There are more againsters than supporters. However, the majority are standing in the middle. Females showed a tendency for a neutral stance. Voters who did not know Bitcoin are unlikely to support it as legal tender.
#
# Although there are around 21% of voters, support Bitcoin to be legal tender, most supporters selected every Bitcoin feature as likely or very likely to contribute their choice. This caused suspicion on the rationality of the votes as some of Bitcoin features, such as "costyMining", did not encourage supporters.
#
# The age distribution is more symmetrical in againsters than in other groups. Moreover, the proportion of againsters steadily increased when the income level or education level increased. Additionally, againsters showed high sensitivity to features "pricingByMajorOwners", "nonIntrinsicValue", "riskyDigitWallet", "fraudTendency" and "costyMining" which could be negatively contribute to Bitcoin's value. It seems that againsters are more rational in their decision compared to supporters and neutrals.
#
# The features of 'freeFromGov', 'Scarcity', 'paymentConvenience','freelyTraded' and 'lowTranscationFee' are significantly considered as unimportant to voters across different voters groups.
#
# Despite all these findings or patterns, all variables are of negligible or weak association with votes. The votes could relate to varieties of reasons, and no feature is strongly correlated with votes.
#
# The public data showed that Bitcoin is not legal tender across countries except El Salvador. Survey data suggests that Bitcoin are poorly supported to be legal tender. It is possible the sharp increase in Bitcoin ownership is driven by the probable gain from price fluctuation. However, this investment behaviour should be cautious as Bitcoin has no intrinsic value, and the legality is poorly supported by both governments and the population. A more vigilant view could be required when conducting Bitcoin studies on price prediction or legality modelling. Moreover, this study suggests that people are more sensitive to risks while the features of 'freeFromGov', 'Scarcity', 'paymentConvenience', 'freelyTraded' and 'lowTranscationFee' may not be as important when considering legal tender. Hence, digital currency development may focus more on risk control.
#
# There is a change of decision to choose Bitcoin legal status public data instead of the cryptocurrency exchange market data from the initial project design. Indeed, the cryptocurrency exchange market data are largely impacted by the change of policies. Such datasets are substantially influenced by many other factors, such as the influence of the attitude of some richest men. Such complexity would cause difficulty in finding the association between two datasets.

# %% [markdown]
# ## References
#
# Abu-Bakar, M.M. (2018) 'Shariah Analysis of Bitcoin, Cryptocurrency, and Blockchain' , *Shariah Analysis in Light of Fatwas and Scholars’ Opinions*, [online]. Available at: https://libertasgh.com/assets/pdf/Shariah_Compliance_Analysis.pdf (Accessed: 19 Mar 2022)
#
#
# Ayers, P., Matthews, C. and Yates, B. (2008) *How Wikipedia works: And how you can be a part of it*. No Starch Press.
#
# Baur, D.G., Hong, K.H. and Lee, A.D. (2018) 'Bitcoin: Medium of exchange or speculative assets?' , *Journal of International Financial Markets, Institutions and Money*, 54 [online]. Available at: https://doi.org/10.1016/j.intfin.2017.12.004 (Accessed: 19 Mar 2022)
#
#
# Cai, C., Li, W., Han, H., Liu, M. 'Risk scenario-based value estimation of Bitcoin', *Procedia Computer Science*, 199 [online]. Available at:  https://doi.org/10.1016/j.procs.2022.01.152 (Accessed: 19 Mar 2022)
#
#
# Dadax Limited (2022) *How many Countries are there in the World?* [online]. Available at: https://www.worldometers.info/geography/how-many-countries-are-there-in-the-world/ (Accessed: 19 Mar 2022)
#
#
# Howarth, J. (2022) *How Many People Own Bitcoin? 95 Blockchain Statistics (2022)* [online]. Available at: https://explodingtopics.com/blog/blockchain-stats (Accessed: 19 Mar 2022)
#
#
# Hui, C.-H., Lo, C.-F., Chau, P.-H and Wong, A. (2020) 'Does Bitcoin behave as a currency?: A standard monetary model approach', *International Review of Financial Analysis*, 70 [online]. Available at: https://doi.org/10.1016/j.irfa.2020.101518 (Accessed: 19 Mar 2022)
#
#
# John, A., Shen, S. and Wilson, T. (2021) *China's top regulators ban crypto trading and mining, sending bitcoin tumbling* [online]. Available at: https://www.reuters.com/world/china/china-central-bank-vows-crackdown-cryptocurrency-trading-2021-09-24/  (Accessed: 19 Mar 2022)
#
#
# Kraken (2022) *Get cryptocurrency prices for 126 assets* [online]. Available at: https://www.kraken.com/prices?quote=USD (Accessed: 19 Mar 2022)
#
#
# Li, Y. 'Research on the Investment Value and Regulation of Bitcoin', *Advances in Economics, Business and Management Research*, 203 [online]. Available at: https://dx.doi.org/10.2991/assehr.k.211209.201  (Accessed: 19 Mar 2022)
#
#
# Luther, W. (2019) 'Getting off the ground: The case of bitcoin', *Journal of Institutional Economics*, 15(2), [online]. Available at: 10.1017/S1744137418000243 (Accessed: 19 Mar 2022)
#
#
# Panagiotidis, T., Stengos T., and Vravosinos, O. (2019) 'The effects of markets, uncertainty and search intensity on bitcoin returns', *International Review of Financial Analysis*, 63, [online]. Available at:  https://doi.org/10.1016/j.irfa.2018.11.002 (Accessed: 19 Mar 2022)
#
#
# Pérez, S. and Ostroff, C. (2021) *El Salvador Becomes First Country to Adopt Bitcoin as National Currency* [online]. Available at: https://www.wsj.com/articles/bitcoin-comes-toel-salvador-first-country-to-adopt-crypto-as-national-currency-11631005200 (Accessed: 19 Mar 2022)
#
#
# Wikipedia (2022) *Fiat money* [online]. Available at: https://en.wikipedia.org/wiki/Fiat_money (Accessed: 19 Mar 2022)
#
#
# Wikipedia (2022) *Legal tender* [online]. Available at: https://en.wikipedia.org/wiki/Legal_tender (Accessed: 19 Mar 2022)
#
#
# Wikipedia (2022) *Legality of cryptocurrency by country or territory* [online]. Available at: https://en.wikipedia.org/wiki/Legality_of_cryptocurrency_by_country_or_territory#External_links (Accessed: 19 Mar 2022)
#
#
# Zhang, Y. (2021) 'A survey project studying on people’s attitude towards Bitcoin', *DSM050: Data Visualization*. University of London. Unpublished essay.

# %% [markdown]
# ## Word Count
#
# The following code will count the number of words in Markdown cells. Code cells are not included.
#
# - `Main word count` is the number of words in the main body of the text, *excluding* references or appendices.
# - `References and appendices word count` is the number of words in any references or appendices.
#
# Only `Main word count` relates to the assignment word limit. There is no limit to the number of words that can be included in references or appendices. Please note that appendices should only be used to provide context or supporting information. *No marks will be directly awarded for material submitted in appendices*.
#
# Important:
#
# - Please do not modify the word count code!
# - To exclude references from your word count **you must** have a cell that starts with the text `## References`. Everything below this cell will not count towards the main word count.
# - If you are submitting additional material as appendices **you must** have a cell that starts with the text `## Appendices`. Everything below this cell will not count towards the main word count. If you do not have any appendices you can delete the `## Appendices` cell.
# - Code comments should only be used to explain details of the implementation, not for discussing your findings. All analysis commentary **must** be written in Markdown cells. *No marks will be awarded for analysis discussion submitted as comments in code cells*.

# %%
# %%js
#
# // Run this cell to update your word count.
#
# function wordcount() {
#     let wordCount = 0
#     let extraCount = 0
#     let mainBody = true
#
#     let cells = Jupyter.notebook.get_cells()
#     cells.forEach((cell) => {
#         if (cell.cell_type == 'markdown') {
#             let text = cell.get_text()
#             // Stop counting as main body when get to References or Appendices.
#             if (text.startsWith('## References') ||
#                 text.startsWith('## Appendices')) {
#                 mainBody = false
#             }
#             if (text.startsWith('## Word Count')) {
#                 text = ''
#             }
#             if (text) {
#                 let words = text.toLowerCase().match(/\b[a-z\d]+\b/g)
#                 if (words) {
#                     let cellCount = words.length
#                     if (mainBody) {
#                         wordCount += cellCount
#                     } else {
#                         extraCount += cellCount
#                     }
#                 }
#             }
#         }
#     })
#     return [wordCount, extraCount]
# }
#
# let wc = wordcount()
# element.append(`Main word count: ${wc[0]} (References and appendices word count: ${wc[1]})`)
